# %% [markdown]
# # Scraping Steam
#
# Este cuaderno Jupyter contiene el codigo fuente encargado de la extraccion automatica de datos desde la plataforma **Steam**. El objetivo es alimentar un modelo de IA con informacion actualizada sobre:
#
# 1.  **Hardware mas utilizado:** Componentes reales que usan los jugadores (GPUs, CPUs, RAM, SO, etc.).
#
# 2.  **Requisitos de videojuegos:** Especificaciones minimas y recomendadas de los titulos mas vendidos.
#
# El proceso genera dos tipos de salidas estructuradas (`CSV` y `JSON`) para su posterior procesamiento en la fase de entrenamiento del modelo.
#
# ### 👨‍💻 Autores del proyecto
#
# * [Alejandro Barrionuevo Rosado](https://github.com/Alejandro-BR)
# * [Alvaro López Guerrero](https://github.com/Alvalogue72)
# * [Andrei Munteanu Popa](https://github.com/andu8705)
#
# Máster de FP en Inteligencia Artifical y Big Data - CPIFP Alan Turing - `Curso 2025/2026`

# %% [markdown]
# ### 1. Configuracion e importacion de librerias
#
# En esta primera celda importamos las herramientas necesarias:
#
# * `requests`: Para realizar las peticiones HTTP a los servidores de Steam.
#
# * `BeautifulSoup`: Para navegar y extraer informacion del codigo HTML.
#
# * `pandas`: Para estructurar los datos en tablas y exportarlos facilmente.
#
# * `re`: Para el uso de expresiones regulares, cruciales para limpiar el texto sucio de los requisitos.
#
# Tambien definimos `GAME_LIMIT`, que determina cuantos juegos analizara el script.

# %%
import os
import time
import re
import requests
import pandas as pd
from bs4 import BeautifulSoup

# Define el volumen de datos a recolectar:
GAME_LIMIT = 6000

# %% [markdown]
# ### 2. Gestion del sistema de archivos
#
# Definimos una funcion auxiliar para mantener el proyecto ordenado. Esta funcion crea automaticamente la estructura de carpetas necesaria (`csv_data` y `json_data`) antes de empezar, asegurando que no haya errores de "ruta no encontrada" al guardar los archivos.

# %%
def create_structure():
    dirs = ['csv_data', 'json_data', 'csv_data/ranked_hardware', 'json_data/ranked_hardware']
    for d in dirs:
        os.makedirs(d, exist_ok=True)

# %% [markdown]
# ### 3. Extraccion de la encuesta de hardware
#
# Esta seccion aborda el *scraping* de la pagina de estadisticas de Steam.
#
# La estructura de esta web es compleja, mezclando encabezados con listas de detalles ocultas. La funcion `get_steam_hardware_survey` implementa la siguiente logica:
#
# 1.  Identifica las filas principales (categorias).
#
# 2.  Busca los contenedores de detalles hijos (`stats_row_details`).
#
# 3.  Asocia correctamente cada componente con su porcentaje de uso real, ignorando filas vacias o datos de cambio mensual irrelevantes.

# %%
# Crea las carpetas y subcarpetas necesarias para almacenar los datos.
def get_steam_hardware_survey():
    url = "https://store.steampowered.com/hwsurvey"
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    
    try:
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text, 'lxml')
        
        data = []
        
        # Buscamos todos los "divs" que sean fila o detalle
        all_divs = soup.find_all('div', class_=lambda x: x and ('stats_row' in x or 'stats_row_details' in x))
        
        current_category = "General"
        
        for div in all_divs:
            classes = div.get('class', [])
            
            # 1. DETECTAR CATEGORIA
            if 'stats_row' in classes and 'stats_row_details' not in classes:
                col_left = div.select_one('.stats_col_left')
                if col_left:
                    text = col_left.get_text(strip=True)
                    if text:
                        current_category = text
            
            # 2. EXTRAER DATOS
            if 'stats_row_details' in classes:
                mids = div.select('.stats_col_mid')   # Nombres de componentes
                rights = div.select('.stats_col_right') # Porcentajes
                
                # Logica para emparejar columnas (evitar columnas de "cambio %")
                pcts = []
                if len(rights) >= 2 * len(mids) and len(mids) > 0:
                    pcts = rights[0::2] # Tomar solo columnas pares
                elif len(rights) == len(mids):
                    pcts = rights
                else:
                    pcts = rights[:len(mids)]
                
                for name_div, pct_div in zip(mids, pcts):
                    item_name = name_div.get_text(strip=True)
                    item_pct = pct_div.get_text(strip=True)
                    
                    if item_name and item_pct:
                        data.append({
                            'category': current_category,
                            'component': item_name,
                            'usage_percentage': item_pct
                        })
                        
        return pd.DataFrame(data)
    except Exception as e:
        print(f"Error scraping Hardware Survey: {e}")
        return pd.DataFrame()

# %% [markdown]
# ### 4. Clasificacion y ranking de hardware
#
# Una vez obtenidos los datos brutos del hardware, necesitamos organizarlos por relevancia. La funcion `save_ranked_hardware` procesa el DataFrame completo y genera tres tipos de archivos:
#
# 1.  **Top 1 (Most Used):** El componente mas popular de cada categoria.
#
# 2.  **Top 2:** El segundo mas popular.
#
# 3.  **Top 3:** El tercero mas popular.
#
# Esto permite al modelo de IA entender la "gama media" y "gama alta" actual del mercado.

# %%
# Funcion auxiliar para guardar en CSV y JSON.
def save_datasets(df, filename_base):
    if df.empty: return
    
    # Reordenar columnas solo si es un dataset de juegos para poner app_id primero
    if 'app_id' in df.columns:
        cols = ['app_id', 'game_name'] + [c for c in df.columns if c not in ['app_id', 'game_name']]
        df = df[cols]
    
    csv_path = os.path.join('csv_data', f'{filename_base}.csv')
    json_path = os.path.join('json_data', f'{filename_base}.json')
    
    df.to_csv(csv_path, index=False, encoding='utf-8')
    df.to_json(json_path, orient='records', indent=4, force_ascii=False)

# Genera los ficheros de ranking por categoria.
def save_ranked_hardware(df):
    if df.empty: return

    # Limpieza
    df = df.copy()
    df['numeric_pct'] = df['usage_percentage'].str.extract(r'(\d+\.?\d*)').astype(float)
    
    # Ordenar
    df_sorted = df.sort_values(by=['category', 'numeric_pct'], ascending=[True, False])
    
    ranks_info = [
        (0, 'top1_hw'),
        (1, 'top2_hw'),
        (2, 'top3_hw')
    ]
    
    for idx, filename in ranks_info:
        # Obtener el n-ésimo elemento de cada grupo
        ranked_df = df_sorted.groupby('category').nth(idx).reset_index()
        
        if 'numeric_pct' in ranked_df.columns:
            ranked_df = ranked_df.drop(columns=['numeric_pct'])
            
        if not ranked_df.empty:
            # Guardamos en la subcarpeta 'ranked_hardware'
            filename_full = f"ranked_hardware/{filename}"
            save_datasets(ranked_df, filename_full)

# %% [markdown]
# ### 5. Obtencion de identificadores de juegos
#
# Steam no permite descargar una lista de un gran volumen juegos en una sola peticion (limita los resultados a 50 o 100 por consulta). Para superar esta barrera, se ha implementado un algoritmo de **paginacion automatica**.
#
# La función `get_top_game_ids`:
#
# 1.  Funciona como un bucle que solicita juegos en **bloques de 50 en 50** (`batch_size = 50`).
#
# 2.  Utiliza un parametro `start` que se incrementa en cada iteracion para avanzar por la lista.
#
# 3.  Acumula los IDs encontrados hasta llegar al `GAME_LIMIT` deseado.
#
# 4.  Incluye una pausa de seguridad de 1.5 segundos entre bloques para evitar que Steam bloquee nuestra conexion por exceso de peticiones.

# %%
def get_top_game_ids(limit=100):
    all_ids = []
    batch_size = 50 # Pedimos bloques de 50 para no saturar ni ser bloqueados
    base_url = "https://store.steampowered.com/search/results/"
    
    # Bucle que avanza de 50 en 50 
    for start in range(0, limit, batch_size):
        params = {
            'query': '',
            'start': start,
            'count': batch_size,
            'dynamic_data': '',
            'sort_by': '_ASC',
            'snr': '1_7_7_7000_7',
            'filter': 'topsellers',
            'infinite': 1,
            'l': 'english'
        }
        
        try:
            response = requests.get(base_url, params=params)
            
            if response.status_code != 200:
                print(f"Error en bloque {start}: Status {response.status_code}")
                continue
                
            json_resp = response.json()
            html = json_resp.get('results_html', '')
            
            if not html:
                print("No se recibieron más datos de Steam.")
                break
                
            soup = BeautifulSoup(html, 'lxml')
            links = soup.select('a.search_result_row')
            
            batch_ids = [link.get('data-ds-appid') for link in links if link.get('data-ds-appid')]
            
            # Evitar duplicados si Steam repite resultados
            new_ids = [bid for bid in batch_ids if bid not in all_ids]
            all_ids.extend(new_ids)
            
            print(f" Bloque {start}-{start+batch_size} obtenido. Total: {len(all_ids)}")
            
            if len(all_ids) >= limit:
                break
                
            time.sleep(1.5) # Pausa importante para evitar bloqueo de IP
            
        except Exception as e:
            print(f"Error obteniendo IDs: {e}")
            break
            
    return all_ids[:limit]

# %% [markdown]
# ### 6. Procesamiento inteligente de texto (Regex y limpieza)
#
# Esta es una de las partes más criticas. Los requisitos en Steam son texto libre (HTML sucio). Aqui utilizamos funciones avanzadas para:
#
# 1.  **Limpiar HTML:** Convertir etiquetas `<br>` en saltos de linea.
#
# 2.  **Eliminar ruido:** Quitamos frases repetitivas como *"Requires a 64-bit processor and operating system"* que confunden al analisis.
#
# 3.  **Parsing con Regex:** Buscamos patrones especificos (`OS:`, `Processor:`, `Memory:`) para separar el texto en columnas utiles.
#
# 4.  **Validacion de procesador:** Si el campo "Processor" contiene texto basura residual ("and operating system"), se anula automaticamente para mantener la calidad del dato.

# %%
def clean_html_text(html_content):
    if not html_content: return ""
    text = str(html_content).replace('<br>', '\n').replace('<br/>', '\n')
    soup = BeautifulSoup(text, 'lxml')
    return soup.get_text(separator='\n', strip=True)

def parse_requirements(raw_text):
    if not raw_text: return None
    
    # 1. Limpieza General y de BOILERPLATE

        # Quitamos etiquetas comunes y la frase problematica de 64-bits
    raw_text = re.sub(r'^(Minimum|Recommended|Mínimo|Recomendado):?', '', raw_text, flags=re.IGNORECASE).strip()
    raw_text = re.sub(r'Requires a 64-bit processor and operating system', '', raw_text, flags=re.IGNORECASE).strip()

        # Patrones Regex para extraer componentes
    patterns = {
        'os': r'(?:OS|Sistema Operativo|SO)\s*:?\s*(.*?)(?=(?:Processor|Procesador|Memory|Memoria|Graphics|Gráficos|DirectX|Storage|Almacenamiento|Sound Card|$))',
        'processor': r'(?:Processor|Procesador)\s*:?\s*(.*?)(?=(?:Memory|Memoria|Graphics|Gráficos|DirectX|Storage|Almacenamiento|Sound Card|OS|Sistema|$))',
        'memory': r'(?:Memory|Memoria)\s*:?\s*(.*?)(?=(?:Graphics|Gráficos|DirectX|Storage|Almacenamiento|Sound Card|OS|Sistema|Processor|$))',
        'graphics': r'(?:Graphics|Gráficos|Video Card|Vídeo)\s*:?\s*(.*?)(?=(?:DirectX|Storage|Almacenamiento|Sound Card|OS|Sistema|Processor|Memory|$))',
        'directx': r'(?:DirectX)\s*:?\s*(.*?)(?=(?:Storage|Almacenamiento|Sound Card|OS|Sistema|Processor|Memory|Graphics|$))',
        'storage': r'(?:Storage|Almacenamiento|Hard Drive)\s*:?\s*(.*?)(?=(?:Sound Card|Additional Notes|Notas|OS|Sistema|$))'
    }

    parsed_data = {}
    found_any = False
    
    for key, pattern in patterns.items():
        match = re.search(pattern, raw_text, re.IGNORECASE | re.DOTALL)
        if match:
            value = match.group(1).strip().strip(',').strip(';')
            parsed_data[key] = value
            if value: found_any = True
        else:
            parsed_data[key] = None
            
        # Si no se encontro ningun campo util, descartamos la fila
    if not found_any: return None

    # 2. FILTRO DE CALIDAD PARA PROCESADOR

        # Si detectamos texto basura en la columna processor, lo marcamos como nulo
    proc_val = parsed_data.get('processor')
    if proc_val and 'and operating system' in proc_val.lower():
        parsed_data['processor'] = None

    return parsed_data

# %% [markdown]
# ### 7. Extraccion masiva de requisitos
#
# Esta funcion itera sobre la lista de IDs de juegos y consulta la **API oficial de Steam** (`appdetails`).
#
# * Fuerza el idioma ingles (`l=english`) para maximizar la compatibilidad del Regex.
#
# * Separa requisitos minimos y recomendados.
#
# * Incluye una pausa (`time.sleep`) para respetar los limites de la API y evitar bloqueos de IP.

# %%
def get_game_requirements(app_ids):
    min_data = []
    rec_data = []
    base_url = "https://store.steampowered.com/api/appdetails"
    
    for idx, app_id in enumerate(app_ids):
        # Log de progreso cada 10 juegos
        if idx % 10 == 0: print(f"Procesando juegos {idx}/{len(app_ids)}")
        
        try:
            r = requests.get(f"{base_url}?appids={app_id}&l=english")
            if r.status_code != 200: continue
            
            data = r.json()
            if not data or str(app_id) not in data or not data[str(app_id)]['success']: continue
                
            game_data = data[str(app_id)]['data']
            game_name = game_data.get('name', 'Unknown')
            pc_reqs = game_data.get('pc_requirements', {})
            
            # Procesar minimos
            if 'minimum' in pc_reqs:
                parsed = parse_requirements(clean_html_text(pc_reqs['minimum']))
                if parsed:
                    entry = {'app_id': app_id, 'game_name': game_name, **parsed}
                    min_data.append(entry)
            
            # Procesar recomendados
            if 'recommended' in pc_reqs:
                parsed = parse_requirements(clean_html_text(pc_reqs['recommended']))
                if parsed:
                    entry = {'app_id': app_id, 'game_name': game_name, **parsed}
                    rec_data.append(entry)
                
            # Pausa de cortesia para la API
            time.sleep(1.2)
            
        except Exception: continue

    return pd.DataFrame(min_data), pd.DataFrame(rec_data)

# %% [markdown]
# ### 8. Ejecucion "main"
#
# Finalmente, orquestamos todo el proceso. Al ejecutar esta celda:
#
# 1.  Se creara la estructura de carpetas.
#
# 2.  Se descargara y procesara la encuesta de hardware.
#
# 3.  Se generaran los rankings de componentes.
#
# 4.  Se obtendran los IDs de los juegos mas vendidos.
#
# 5.  Se extraeran y limpiaran sus requisitos.
#
# 6.  Todo se guardara en las carpetas `csv_data` y `json_data`.

# %%
def main():
    # Creando proceso de resolucion de datos
    create_structure()
    
    # PASO 1: Hardware
        # Analizando encuesta de hardware de Steam
    df_hw = get_steam_hardware_survey()
    save_datasets(df_hw, 'hw_survey_full')
    
        # Generando rankings de hardware
    save_ranked_hardware(df_hw)
    
    # PASO 2: IDs de Juegos
    print(f"\nObteniendo top {GAME_LIMIT} juegos mas vendidos...")
    ids = get_top_game_ids(limit=GAME_LIMIT)
    print(f"\nIDs recolectados: {len(ids)}\n")
    
    # PASO 3: Requisitos
        # Extrayendo y limpiando requisitos
    df_min, df_rec = get_game_requirements(ids)
    
    save_datasets(df_min, 'req_minimos')
    save_datasets(df_rec, 'req_recomendados')
    
    print("\n--- Proceso completado exitosamente ---")

if __name__ == "__main__":
    main()
# Autor: Munteanu Popa, Andrei
# Out:
# Obteniendo top 6000 juegos mas vendidos...
#  Bloque 0-50 obtenido. Total: 50
#  Bloque 50-100 obtenido. Total: 100
#  Bloque 100-150 obtenido. Total: 150
#  Bloque 150-200 obtenido. Total: 200
#  Bloque 200-250 obtenido. Total: 250
#  Bloque 250-300 obtenido. Total: 300
#  Bloque 300-350 obtenido. Total: 350
#  Bloque 350-400 obtenido. Total: 400
#  Bloque 400-450 obtenido. Total: 450
#  Bloque 450-500 obtenido. Total: 500
#  Bloque 500-550 obtenido. Total: 550
#  Bloque 550-600 obtenido. Total: 600
#  Bloque 600-650 obtenido. Total: 650
#  Bloque 650-700 obtenido. Total: 699
#  Bloque 700-750 obtenido. Total: 749
#  Bloque 750-800 obtenido. Total: 799
#  Bloque 800-850 obtenido. Total: 849
#  Bloque 850-900 obtenido. Total: 899
#  Bloque 900-950 obtenido. Total: 949
#  Bloque 950-1000 obtenido. Total: 999
#  Bloque 1000-1050 obtenido. Total: 1049
#  Bloque 1050-1100 obtenido. Total: 1099
#  Bloque 1100-1150 obtenido. Total: 1149
#  Bloque 1150-1200 obtenido. Total: 1199
#  Bloque 1200-1250 obtenido. Total: 1249
#  Bloque 1250-1300 obtenido. Total: 1299
#  Bloque 1300-1350 obtenido. Total: 1348
#  Bloque 1350-1400 obtenido. Total: 1398
#  Bloque 1400-1450 obtenido. Total: 1448
#  Bloque 1450-1500 obtenido. Total: 1498
#  Bloque 1500-1550 obtenido. Total: 1548
#  Bloque 1550-1600 obtenido. Total: 1596
#  Bloque 1600-1650 obtenido. Total: 1646
#  Bloque 1650-1700 obtenido. Total: 1695
#  Bloque 1700-1750 obtenido. Total: 1744
#  Bloque 1750-1800 obtenido. Total: 1794
#  Bloque 1800-1850 obtenido. Total: 1844
#  Bloque 1850-1900 obtenido. Total: 1894
#  Bloque 1900-1950 obtenido. Total: 1943
#  Bloque 1950-2000 obtenido. Total: 1993
#  Bloque 2000-2050 obtenido. Total: 2043
#  Bloque 2050-2100 obtenido. Total: 2093
#  Bloque 2100-2150 obtenido. Total: 2143
#  Bloque 2150-2200 obtenido. Total: 2193
#  Bloque 2200-2250 obtenido. Total: 2242
#  Bloque 2250-2300 obtenido. Total: 2291
#  Bloque 2300-2350 obtenido. Total: 2341
#  Bloque 2350-2400 obtenido. Total: 2391
#  Bloque 2400-2450 obtenido. Total: 2441
#  Bloque 2450-2500 obtenido. Total: 2491
#  Bloque 2500-2550 obtenido. Total: 2541
#  Bloque 2550-2600 obtenido. Total: 2591
#  Bloque 2600-2650 obtenido. Total: 2641
#  Bloque 2650-2700 obtenido. Total: 2691
#  Bloque 2700-2750 obtenido. Total: 2741
#  Bloque 2750-2800 obtenido. Total: 2791
#  Bloque 2800-2850 obtenido. Total: 2841
#  Bloque 2850-2900 obtenido. Total: 2891
#  Bloque 2900-2950 obtenido. Total: 2941
#  Bloque 2950-3000 obtenido. Total: 2991
#  Bloque 3000-3050 obtenido. Total: 3041
#  Bloque 3050-3100 obtenido. Total: 3089
#  Bloque 3100-3150 obtenido. Total: 3139
#  Bloque 3150-3200 obtenido. Total: 3189
#  Bloque 3200-3250 obtenido. Total: 3239
#  Bloque 3250-3300 obtenido. Total: 3289
#  Bloque 3300-3350 obtenido. Total: 3338
#  Bloque 3350-3400 obtenido. Total: 3388
#  Bloque 3400-3450 obtenido. Total: 3438
#  Bloque 3450-3500 obtenido. Total: 3488
#  Bloque 3500-3550 obtenido. Total: 3538
#  Bloque 3550-3600 obtenido. Total: 3587
#  Bloque 3600-3650 obtenido. Total: 3637
#  Bloque 3650-3700 obtenido. Total: 3686
#  Bloque 3700-3750 obtenido. Total: 3736
#  Bloque 3750-3800 obtenido. Total: 3786
#  Bloque 3800-3850 obtenido. Total: 3836
#  Bloque 3850-3900 obtenido. Total: 3885
#  Bloque 3900-3950 obtenido. Total: 3935
#  Bloque 3950-4000 obtenido. Total: 3985
#  Bloque 4000-4050 obtenido. Total: 4035
#  Bloque 4050-4100 obtenido. Total: 4085
#  Bloque 4100-4150 obtenido. Total: 4135
#  Bloque 4150-4200 obtenido. Total: 4185
#  Bloque 4200-4250 obtenido. Total: 4235
#  Bloque 4250-4300 obtenido. Total: 4285
#  Bloque 4300-4350 obtenido. Total: 4335
#  Bloque 4350-4400 obtenido. Total: 4385
#  Bloque 4400-4450 obtenido. Total: 4434
#  Bloque 4450-4500 obtenido. Total: 4484
#  Bloque 4500-4550 obtenido. Total: 4534
#  Bloque 4550-4600 obtenido. Total: 4582
#  Bloque 4600-4650 obtenido. Total: 4632
#  Bloque 4650-4700 obtenido. Total: 4682
#  Bloque 4700-4750 obtenido. Total: 4732
#  Bloque 4750-4800 obtenido. Total: 4782
#  Bloque 4800-4850 obtenido. Total: 4832
#  Bloque 4850-4900 obtenido. Total: 4882
#  Bloque 4900-4950 obtenido. Total: 4932
#  Bloque 4950-5000 obtenido. Total: 4982
#  Bloque 5000-5050 obtenido. Total: 5031
#  Bloque 5050-5100 obtenido. Total: 5081
#  Bloque 5100-5150 obtenido. Total: 5131
#  Bloque 5150-5200 obtenido. Total: 5181
#  Bloque 5200-5250 obtenido. Total: 5231
#  Bloque 5250-5300 obtenido. Total: 5281
#  Bloque 5300-5350 obtenido. Total: 5331
#  Bloque 5350-5400 obtenido. Total: 5381
#  Bloque 5400-5450 obtenido. Total: 5431
#  Bloque 5450-5500 obtenido. Total: 5481
#  Bloque 5500-5550 obtenido. Total: 5531
#  Bloque 5550-5600 obtenido. Total: 5581
#  Bloque 5600-5650 obtenido. Total: 5629
#  Bloque 5650-5700 obtenido. Total: 5675
#  Bloque 5700-5750 obtenido. Total: 5675
#  Bloque 5750-5800 obtenido. Total: 5675
#  Bloque 5800-5850 obtenido. Total: 5675
#  Bloque 5850-5900 obtenido. Total: 5675
#  Bloque 5900-5950 obtenido. Total: 5675
#  Bloque 5950-6000 obtenido. Total: 5675
#
# IDs recolectados: 5675
#
# Procesando juegos 0/5675
# Procesando juegos 10/5675
# Procesando juegos 20/5675
# Procesando juegos 30/5675
# Procesando juegos 40/5675
# Procesando juegos 50/5675
# Procesando juegos 60/5675
# Procesando juegos 70/5675
# Procesando juegos 80/5675
# Procesando juegos 90/5675
# Procesando juegos 100/5675
# Procesando juegos 110/5675
# Procesando juegos 120/5675
# Procesando juegos 130/5675
# Procesando juegos 140/5675
# Procesando juegos 150/5675
# Procesando juegos 160/5675
# Procesando juegos 170/5675
# Procesando juegos 180/5675
# Procesando juegos 190/5675
# Procesando juegos 200/5675
# Procesando juegos 210/5675
# Procesando juegos 220/5675
# Procesando juegos 230/5675
# Procesando juegos 240/5675
# Procesando juegos 250/5675
# Procesando juegos 260/5675
# Procesando juegos 270/5675
# Procesando juegos 280/5675
# Procesando juegos 290/5675
# Procesando juegos 300/5675
# Procesando juegos 310/5675
# Procesando juegos 320/5675
# Procesando juegos 330/5675
# Procesando juegos 340/5675
# Procesando juegos 350/5675
# Procesando juegos 360/5675
# Procesando juegos 370/5675
# Procesando juegos 380/5675
# Procesando juegos 390/5675
# Procesando juegos 400/5675
# Procesando juegos 410/5675
# Procesando juegos 420/5675
# Procesando juegos 430/5675
# Procesando juegos 440/5675
# Procesando juegos 450/5675
# Procesando juegos 460/5675
# Procesando juegos 470/5675
# Procesando juegos 480/5675
# Procesando juegos 490/5675
# Procesando juegos 500/5675
# Procesando juegos 510/5675
# Procesando juegos 520/5675
# Procesando juegos 530/5675
# Procesando juegos 540/5675
# Procesando juegos 550/5675
# Procesando juegos 560/5675
# Procesando juegos 570/5675
# Procesando juegos 580/5675
# Procesando juegos 590/5675
# Procesando juegos 600/5675
# Procesando juegos 610/5675
# Procesando juegos 620/5675
# Procesando juegos 630/5675
# Procesando juegos 640/5675
# Procesando juegos 650/5675
# Procesando juegos 660/5675
# Procesando juegos 670/5675
# Procesando juegos 680/5675
# Procesando juegos 690/5675
# Procesando juegos 700/5675
# Procesando juegos 710/5675
# Procesando juegos 720/5675
# Procesando juegos 730/5675
# Procesando juegos 740/5675
# Procesando juegos 750/5675
# Procesando juegos 760/5675
# Procesando juegos 770/5675
# Procesando juegos 780/5675
# Procesando juegos 790/5675
# Procesando juegos 800/5675
# Procesando juegos 810/5675
# Procesando juegos 820/5675
# Procesando juegos 830/5675
# Procesando juegos 840/5675
# Procesando juegos 850/5675
# Procesando juegos 860/5675
# Procesando juegos 870/5675
# Procesando juegos 880/5675
# Procesando juegos 890/5675
# Procesando juegos 900/5675
# Procesando juegos 910/5675
# Procesando juegos 920/5675
# Procesando juegos 930/5675
# Procesando juegos 940/5675
# Procesando juegos 950/5675
# Procesando juegos 960/5675
# Procesando juegos 970/5675
# Procesando juegos 980/5675
# Procesando juegos 990/5675
# Procesando juegos 1000/5675
# Procesando juegos 1010/5675
# Procesando juegos 1020/5675
# Procesando juegos 1030/5675
# Procesando juegos 1040/5675
# Procesando juegos 1050/5675
# Procesando juegos 1060/5675
# Procesando juegos 1070/5675
# Procesando juegos 1080/5675
# Procesando juegos 1090/5675
# Procesando juegos 1100/5675
# Procesando juegos 1110/5675
# Procesando juegos 1120/5675
# Procesando juegos 1130/5675
# Procesando juegos 1140/5675
# Procesando juegos 1150/5675
# Procesando juegos 1160/5675
# Procesando juegos 1170/5675
# Procesando juegos 1180/5675
# Procesando juegos 1190/5675
# Procesando juegos 1200/5675
# Procesando juegos 1210/5675
# Procesando juegos 1220/5675
# Procesando juegos 1230/5675
# Procesando juegos 1240/5675
# Procesando juegos 1250/5675
# Procesando juegos 1260/5675
# Procesando juegos 1270/5675
# Procesando juegos 1280/5675
# Procesando juegos 1290/5675
# Procesando juegos 1300/5675
# Procesando juegos 1310/5675
# Procesando juegos 1320/5675
# Procesando juegos 1330/5675
# Procesando juegos 1340/5675
# Procesando juegos 1350/5675
# Procesando juegos 1360/5675
# Procesando juegos 1370/5675
# Procesando juegos 1380/5675
# Procesando juegos 1390/5675
# Procesando juegos 1400/5675
# Procesando juegos 1410/5675
# Procesando juegos 1420/5675
# Procesando juegos 1430/5675
# Procesando juegos 1440/5675
# Procesando juegos 1450/5675
# Procesando juegos 1460/5675
# Procesando juegos 1470/5675
# Procesando juegos 1480/5675
# Procesando juegos 1490/5675
# Procesando juegos 1500/5675
# Procesando juegos 1510/5675
# Procesando juegos 1520/5675
# Procesando juegos 1530/5675
# Procesando juegos 1540/5675
# Procesando juegos 1550/5675
# Procesando juegos 1560/5675
# Procesando juegos 1570/5675
# Procesando juegos 1580/5675
# Procesando juegos 1590/5675
# Procesando juegos 1600/5675
# Procesando juegos 1610/5675
# Procesando juegos 1620/5675
# Procesando juegos 1630/5675
# Procesando juegos 1640/5675
# Procesando juegos 1650/5675
# Procesando juegos 1660/5675
# Procesando juegos 1670/5675
# Procesando juegos 1680/5675
# Procesando juegos 1690/5675
# Procesando juegos 1700/5675
# Procesando juegos 1710/5675
# Procesando juegos 1720/5675
# Procesando juegos 1730/5675
# Procesando juegos 1740/5675
# Procesando juegos 1750/5675
# Procesando juegos 1760/5675
# Procesando juegos 1770/5675
# Procesando juegos 1780/5675
# Procesando juegos 1790/5675
# Procesando juegos 1800/5675
# Procesando juegos 1810/5675
# Procesando juegos 1820/5675
# Procesando juegos 1830/5675
# Procesando juegos 1840/5675
# Procesando juegos 1850/5675
# Procesando juegos 1860/5675
# Procesando juegos 1870/5675
# Procesando juegos 1880/5675
# Procesando juegos 1890/5675
# Procesando juegos 1900/5675
# Procesando juegos 1910/5675
# Procesando juegos 1920/5675
# Procesando juegos 1930/5675
# Procesando juegos 1940/5675
# Procesando juegos 1950/5675
# Procesando juegos 1960/5675
# Procesando juegos 1970/5675
# Procesando juegos 1980/5675
# Procesando juegos 1990/5675
# Procesando juegos 2000/5675
# Procesando juegos 2010/5675
# Procesando juegos 2020/5675
# Procesando juegos 2030/5675
# Procesando juegos 2040/5675
# Procesando juegos 2050/5675
# Procesando juegos 2060/5675
# Procesando juegos 2070/5675
# Procesando juegos 2080/5675
# Procesando juegos 2090/5675
# Procesando juegos 2100/5675
# Procesando juegos 2110/5675
# Procesando juegos 2120/5675
# Procesando juegos 2130/5675
# Procesando juegos 2140/5675
# Procesando juegos 2150/5675
# Procesando juegos 2160/5675
# Procesando juegos 2170/5675
# Procesando juegos 2180/5675
# Procesando juegos 2190/5675
# Procesando juegos 2200/5675
# Procesando juegos 2210/5675
# Procesando juegos 2220/5675
# Procesando juegos 2230/5675
# Procesando juegos 2240/5675
# Procesando juegos 2250/5675
# Procesando juegos 2260/5675
# Procesando juegos 2270/5675
# Procesando juegos 2280/5675
# Procesando juegos 2290/5675
# Procesando juegos 2300/5675
# Procesando juegos 2310/5675
# Procesando juegos 2320/5675
# Procesando juegos 2330/5675
# Procesando juegos 2340/5675
# Procesando juegos 2350/5675
# Procesando juegos 2360/5675
# Procesando juegos 2370/5675
# Procesando juegos 2380/5675
# Procesando juegos 2390/5675
# Procesando juegos 2400/5675
# Procesando juegos 2410/5675
# Procesando juegos 2420/5675
# Procesando juegos 2430/5675
# Procesando juegos 2440/5675
# Procesando juegos 2450/5675
# Procesando juegos 2460/5675
# Procesando juegos 2470/5675
# Procesando juegos 2480/5675
# Procesando juegos 2490/5675
# Procesando juegos 2500/5675
# Procesando juegos 2510/5675
# Procesando juegos 2520/5675
# Procesando juegos 2530/5675
# Procesando juegos 2540/5675
# Procesando juegos 2550/5675
# Procesando juegos 2560/5675
# Procesando juegos 2570/5675
# Procesando juegos 2580/5675
# Procesando juegos 2590/5675
# Procesando juegos 2600/5675
# Procesando juegos 2610/5675
# Procesando juegos 2620/5675
# Procesando juegos 2630/5675
# Procesando juegos 2640/5675
# Procesando juegos 2650/5675
# Procesando juegos 2660/5675
# Procesando juegos 2670/5675
# Procesando juegos 2680/5675
# Procesando juegos 2690/5675
# Procesando juegos 2700/5675
# Procesando juegos 2710/5675
# Procesando juegos 2720/5675
# Procesando juegos 2730/5675
# Procesando juegos 2740/5675
# Procesando juegos 2750/5675
# Procesando juegos 2760/5675
# Procesando juegos 2770/5675
# Procesando juegos 2780/5675
# Procesando juegos 2790/5675
# Procesando juegos 2800/5675
# Procesando juegos 2810/5675
# Procesando juegos 2820/5675
# Procesando juegos 2830/5675
# Procesando juegos 2840/5675
# Procesando juegos 2850/5675
# Procesando juegos 2860/5675
# Procesando juegos 2870/5675
# Procesando juegos 2880/5675
# Procesando juegos 2890/5675
# Procesando juegos 2900/5675
# Procesando juegos 2910/5675
# Procesando juegos 2920/5675
# Procesando juegos 2930/5675
# Procesando juegos 2940/5675
# Procesando juegos 2950/5675
# Procesando juegos 2960/5675
# Procesando juegos 2970/5675
# Procesando juegos 2980/5675
# Procesando juegos 2990/5675
# Procesando juegos 3000/5675
# Procesando juegos 3010/5675
# Procesando juegos 3020/5675
# Procesando juegos 3030/5675
# Procesando juegos 3040/5675
# Procesando juegos 3050/5675
# Procesando juegos 3060/5675
# Procesando juegos 3070/5675
# Procesando juegos 3080/5675
# Procesando juegos 3090/5675
# Procesando juegos 3100/5675
# Procesando juegos 3110/5675
# Procesando juegos 3120/5675
# Procesando juegos 3130/5675
# Procesando juegos 3140/5675
# Procesando juegos 3150/5675
# Procesando juegos 3160/5675
# Procesando juegos 3170/5675
# Procesando juegos 3180/5675
# Procesando juegos 3190/5675
# Procesando juegos 3200/5675
# Procesando juegos 3210/5675
# Procesando juegos 3220/5675
# Procesando juegos 3230/5675
# Procesando juegos 3240/5675
# Procesando juegos 3250/5675
# Procesando juegos 3260/5675
# Procesando juegos 3270/5675
# Procesando juegos 3280/5675
# Procesando juegos 3290/5675
# Procesando juegos 3300/5675
# Procesando juegos 3310/5675
# Procesando juegos 3320/5675
# Procesando juegos 3330/5675
# Procesando juegos 3340/5675
# Procesando juegos 3350/5675
# Procesando juegos 3360/5675
# Procesando juegos 3370/5675
# Procesando juegos 3380/5675
# Procesando juegos 3390/5675
# Procesando juegos 3400/5675
# Procesando juegos 3410/5675
# Procesando juegos 3420/5675
# Procesando juegos 3430/5675
# Procesando juegos 3440/5675
# Procesando juegos 3450/5675
# Procesando juegos 3460/5675
# Procesando juegos 3470/5675
# Procesando juegos 3480/5675
# Procesando juegos 3490/5675
# Procesando juegos 3500/5675
# Procesando juegos 3510/5675
# Procesando juegos 3520/5675
# Procesando juegos 3530/5675
# Procesando juegos 3540/5675
# Procesando juegos 3550/5675
# Procesando juegos 3560/5675
# Procesando juegos 3570/5675
# Procesando juegos 3580/5675
# Procesando juegos 3590/5675
# Procesando juegos 3600/5675
# Procesando juegos 3610/5675
# Procesando juegos 3620/5675
# Procesando juegos 3630/5675
# Procesando juegos 3640/5675
# Procesando juegos 3650/5675
# Procesando juegos 3660/5675
# Procesando juegos 3670/5675
# Procesando juegos 3680/5675
# Procesando juegos 3690/5675
# Procesando juegos 3700/5675
# Procesando juegos 3710/5675
# Procesando juegos 3720/5675
# Procesando juegos 3730/5675
# Procesando juegos 3740/5675
# Procesando juegos 3750/5675
# Procesando juegos 3760/5675
# Procesando juegos 3770/5675
# Procesando juegos 3780/5675
# Procesando juegos 3790/5675
# Procesando juegos 3800/5675
# Procesando juegos 3810/5675
# Procesando juegos 3820/5675
# Procesando juegos 3830/5675
# Procesando juegos 3840/5675
# Procesando juegos 3850/5675
# Procesando juegos 3860/5675
# Procesando juegos 3870/5675
# Procesando juegos 3880/5675
# Procesando juegos 3890/5675
# Procesando juegos 3900/5675
# Procesando juegos 3910/5675
# Procesando juegos 3920/5675
# Procesando juegos 3930/5675
# Procesando juegos 3940/5675
# Procesando juegos 3950/5675
# Procesando juegos 3960/5675
# Procesando juegos 3970/5675
# Procesando juegos 3980/5675
# Procesando juegos 3990/5675
# Procesando juegos 4000/5675
# Procesando juegos 4010/5675
# Procesando juegos 4020/5675
# Procesando juegos 4030/5675
# Procesando juegos 4040/5675
# Procesando juegos 4050/5675
# Procesando juegos 4060/5675
# Procesando juegos 4070/5675
# Procesando juegos 4080/5675
# Procesando juegos 4090/5675
# Procesando juegos 4100/5675
# Procesando juegos 4110/5675
# Procesando juegos 4120/5675
# Procesando juegos 4130/5675
# Procesando juegos 4140/5675
# Procesando juegos 4150/5675
# Procesando juegos 4160/5675
# Procesando juegos 4170/5675
# Procesando juegos 4180/5675
# Procesando juegos 4190/5675
# Procesando juegos 4200/5675
# Procesando juegos 4210/5675
# Procesando juegos 4220/5675
# Procesando juegos 4230/5675
# Procesando juegos 4240/5675
# Procesando juegos 4250/5675
# Procesando juegos 4260/5675
# Procesando juegos 4270/5675
# Procesando juegos 4280/5675
# Procesando juegos 4290/5675
# Procesando juegos 4300/5675
# Procesando juegos 4310/5675
# Procesando juegos 4320/5675
# Procesando juegos 4330/5675
# Procesando juegos 4340/5675
# Procesando juegos 4350/5675
# Procesando juegos 4360/5675
# Procesando juegos 4370/5675
# Procesando juegos 4380/5675
# Procesando juegos 4390/5675
# Procesando juegos 4400/5675
# Procesando juegos 4410/5675
# Procesando juegos 4420/5675
# Procesando juegos 4430/5675
# Procesando juegos 4440/5675
# Procesando juegos 4450/5675
# Procesando juegos 4460/5675
# Procesando juegos 4470/5675
# Procesando juegos 4480/5675
# Procesando juegos 4490/5675
# Procesando juegos 4500/5675
# Procesando juegos 4510/5675
# Procesando juegos 4520/5675
# Procesando juegos 4530/5675
# Procesando juegos 4540/5675
# Procesando juegos 4550/5675
# Procesando juegos 4560/5675
# Procesando juegos 4570/5675
# Procesando juegos 4580/5675
# Procesando juegos 4590/5675
# Procesando juegos 4600/5675
# Procesando juegos 4610/5675
# Procesando juegos 4620/5675
# Procesando juegos 4630/5675
# Procesando juegos 4640/5675
# Procesando juegos 4650/5675
# Procesando juegos 4660/5675
# Procesando juegos 4670/5675
# Procesando juegos 4680/5675
# Procesando juegos 4690/5675
# Procesando juegos 4700/5675
# Procesando juegos 4710/5675
# Procesando juegos 4720/5675
# Procesando juegos 4730/5675
# Procesando juegos 4740/5675
# Procesando juegos 4750/5675
# Procesando juegos 4760/5675
# Procesando juegos 4770/5675
# Procesando juegos 4780/5675
# Procesando juegos 4790/5675
# Procesando juegos 4800/5675
# Procesando juegos 4810/5675
# Procesando juegos 4820/5675
# Procesando juegos 4830/5675
# Procesando juegos 4840/5675
# Procesando juegos 4850/5675
# Procesando juegos 4860/5675
# Procesando juegos 4870/5675
# Procesando juegos 4880/5675
# Procesando juegos 4890/5675
# Procesando juegos 4900/5675
# Procesando juegos 4910/5675
# Procesando juegos 4920/5675
# Procesando juegos 4930/5675
# Procesando juegos 4940/5675
# Procesando juegos 4950/5675
# Procesando juegos 4960/5675
# Procesando juegos 4970/5675
# Procesando juegos 4980/5675
# Procesando juegos 4990/5675
# Procesando juegos 5000/5675
# Procesando juegos 5010/5675
# Procesando juegos 5020/5675
# Procesando juegos 5030/5675
# Procesando juegos 5040/5675
# Procesando juegos 5050/5675
# Procesando juegos 5060/5675
# Procesando juegos 5070/5675
# Procesando juegos 5080/5675
# Procesando juegos 5090/5675
# Procesando juegos 5100/5675
# Procesando juegos 5110/5675
# Procesando juegos 5120/5675
# Procesando juegos 5130/5675
# Procesando juegos 5140/5675
# Procesando juegos 5150/5675
# Procesando juegos 5160/5675
# Procesando juegos 5170/5675
# Procesando juegos 5180/5675
# Procesando juegos 5190/5675
# Procesando juegos 5200/5675
# Procesando juegos 5210/5675
# Procesando juegos 5220/5675
# Procesando juegos 5230/5675
# Procesando juegos 5240/5675
# Procesando juegos 5250/5675
# Procesando juegos 5260/5675
# Procesando juegos 5270/5675
# Procesando juegos 5280/5675
# Procesando juegos 5290/5675
# Procesando juegos 5300/5675
# Procesando juegos 5310/5675
# Procesando juegos 5320/5675
# Procesando juegos 5330/5675
# Procesando juegos 5340/5675
# Procesando juegos 5350/5675
# Procesando juegos 5360/5675
# Procesando juegos 5370/5675
# Procesando juegos 5380/5675
# Procesando juegos 5390/5675
# Procesando juegos 5400/5675
# Procesando juegos 5410/5675
# Procesando juegos 5420/5675
# Procesando juegos 5430/5675
# Procesando juegos 5440/5675
# Procesando juegos 5450/5675
# Procesando juegos 5460/5675
# Procesando juegos 5470/5675
# Procesando juegos 5480/5675
# Procesando juegos 5490/5675
# Procesando juegos 5500/5675
# Procesando juegos 5510/5675
# Procesando juegos 5520/5675
# Procesando juegos 5530/5675
# Procesando juegos 5540/5675
# Procesando juegos 5550/5675
# Procesando juegos 5560/5675
# Procesando juegos 5570/5675
# Procesando juegos 5580/5675
# Procesando juegos 5590/5675
# Procesando juegos 5600/5675
# Procesando juegos 5610/5675
# Procesando juegos 5620/5675
# Procesando juegos 5630/5675
# Procesando juegos 5640/5675
# Procesando juegos 5650/5675
# Procesando juegos 5660/5675
# Procesando juegos 5670/5675
#
# --- Proceso completado exitosamente ---
